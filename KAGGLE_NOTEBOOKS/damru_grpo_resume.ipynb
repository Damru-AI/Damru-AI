# %%
# DAMRU GRPO RESUME
# Seedha ek cell mein paste karo aur Run All karo!
# HF_TOKEN Kaggle Secret mein hona chahiye.
import os, urllib.request
url = 'https://raw.githubusercontent.com/Damru-AI/Damru-AI/main/damru_grpo_resume.py'
urllib.request.urlretrieve(url, 'damru_grpo_resume.py')
exec(open('damru_grpo_resume.py').read())
